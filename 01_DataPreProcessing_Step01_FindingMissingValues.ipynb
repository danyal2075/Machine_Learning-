# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('../data.csv')

# %%
dataset
# Out:
#           trip_id  year  month  week  day  hour    usertype  gender  \
# 0         2355134  2014      6    27    0    23  Subscriber    Male
# 1         2355133  2014      6    27    0    23  Subscriber    Male
# 2         2355130  2014      6    27    0    23  Subscriber    Male
# 3         2355129  2014      6    27    0    23  Subscriber  Female
# 4         2355128  2014      6    27    0    23  Subscriber  Female
# ...           ...   ...    ...   ...  ...   ...         ...     ...
# 9495230  16734072  2017     10    39    6     0  Subscriber  Female
# 9495231  16734071  2017     10    39    6     0  Subscriber    Male
# 9495232  16734070  2017     10    39    6     0  Subscriber    Male
# 9495233  16734067  2017     10    39    6     0  Subscriber  Female
# 9495234  16734066  2017     10    39    6     0  Subscriber  Female
#
#                    starttime             stoptime  ...  from_station_id  \
# 0        2014-06-30 23:57:00  2014-07-01 00:07:00  ...              131
# ...

# %%
dataset['year'] # to get the specific row of the data
# Out:
# 0          2014
# 1          2014
# 2          2014
# 3          2014
# 4          2014
#            ...
# 9495230    2017
# 9495231    2017
# 9495232    2017
# 9495233    2017
# 9495234    2017
# Name: year, Length: 9495235, dtype: int64

# %%
# to get more rows of the data. we can save it in a variable to use it further
dataset[['year','gender']]
# Out:
#          year  gender
# 0        2014    Male
# 1        2014    Male
# 2        2014    Male
# 3        2014  Female
# 4        2014  Female
# ...       ...     ...
# 9495230  2017  Female
# 9495231  2017    Male
# 9495232  2017    Male
# 9495233  2017  Female
# 9495234  2017  Female
#
# [9495235 rows x 2 columns]

# %%
# we can get how many times the specific value if repeated.
dataset[['year','gender']].value_counts()
# Out:
# year  gender
# 2017  Male      2218381
# 2016  Male      2018964
# 2015  Male      1660100
# 2014  Male      1219115
# 2017  Female     739309
# 2016  Female     682389
# 2015  Female     560409
# 2014  Female     396568
# dtype: int64

# %%
# we can get unique values of a specific row.
dataset['year'].unique()
# Out:
# array([2014, 2015, 2016, 2017], dtype=int64)

# %%
# check out the type of the data
x = dataset[['year','gender']]
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dataset['year'] == 2014
# print(len(s))
# print(s)
# print(type(s))
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 9495230    False
# 9495231    False
# 9495232    False
# 9495233    False
# 9495234    False
# Name: year, Length: 9495235, dtype: bool

# %%
dataset[dataset['year'] == 2014]
# Out:
#          trip_id  year  month  week  day  hour    usertype  gender  \
# 0        2355134  2014      6    27    0    23  Subscriber    Male
# 1        2355133  2014      6    27    0    23  Subscriber    Male
# 2        2355130  2014      6    27    0    23  Subscriber    Male
# 3        2355129  2014      6    27    0    23  Subscriber  Female
# 4        2355128  2014      6    27    0    23  Subscriber  Female
# ...          ...   ...    ...   ...  ...   ...         ...     ...
# 1615678  3810756  2014     10    40    2     0  Subscriber    Male
# 1615679  3810754  2014     10    40    2     0  Subscriber    Male
# 1615680  3810753  2014     10    40    2     0  Subscriber    Male
# 1615681  3810752  2014     10    40    2     0  Subscriber    Male
# 1615682  3810751  2014     10    40    2     0  Subscriber    Male
#
#                    starttime             stoptime  ...  from_station_id  \
# 0        2014-06-30 23:57:00  2014-07-01 00:07:00  ...              131
# ...

# %%
# to get the data in the form of array
x = dataset[['year','gender']].values
print(x)
print(type(x))
# Out:
# [[2014 'Male']
#  [2014 'Male']
#  [2014 'Male']
#  ...
#  [2017 'Male']
#  [2017 'Female']
#  [2017 'Female']]
# <class 'numpy.ndarray'>

# %%
#to find out which row has missing values but fortunatly this data has no missing value
dataset.loc[dataset.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [trip_id, year, month, week, day, hour, usertype, gender, starttime, stoptime, tripduration, temperature, events, from_station_id, from_station_name, latitude_start, longitude_start, dpcapacity_start, to_station_id, to_station_name, latitude_end, longitude_end, dpcapacity_end]
# Index: []
#
# [0 rows x 23 columns]

# %%
li = x.tolist()
# print(li)
print(type(li))
# Out:
# <class 'list'>
