# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# defining the name of the columns manually because they are not given in the data
cols = ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1','fAsym','fM3Long', 'fM3Trans', 'fAlpha', 'fDist', 'class']
df = pd.read_csv('magic04.data', names=cols)

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist class
# 0       -8.2027  40.0920   81.8828     g
# 1       -9.9574   6.3609  205.2610     g
# ...

# %%
# converting the label into binary 
df['class'] = (df['class'] == 'g').astype(int)

# %%
df['class'].unique() # 1 is for 'g' and 0 is for 'h'
# Out:
# array([1, 0])

# %%
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
# now we are going to check the values of the features for each class.
# for gamma
df_gamma = df[df['class'] == 1]
df_gamma
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525
# ...         ...       ...     ...     ...     ...       ...      ...
# 12327   12.8703   11.4444  2.3811  0.7360  0.3805  -15.0946   5.3032
# 12328   26.8595   20.5946  2.8754  0.3438  0.2152   -3.4556 -20.0014
# 12329   22.0913   10.8949  2.2945  0.5381  0.2919   15.2776  18.2296
# 12330   56.2216   18.7019  2.9297  0.2516  0.1393   96.5758 -41.2969
# 12331   31.5125   19.2867  2.9578  0.2975  0.1515   38.1833  21.6729
#
#        fM3Trans   fAlpha     fDist  class
# 0       -8.2027  40.0920   81.8828      1
# 1       -9.9574   6.3609  205.2610      1
# ...

# %%
# now to check for hadron
df_hadron = df[df['class'] == 0]
df_hadron
# Out:
#         fLength   fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 12332   93.7035  37.9432  3.1454  0.1680  0.1011   53.2566   89.0566
# 12333  102.0005  22.0017  3.3161  0.1064  0.0724  -54.0862   43.0553
# 12334  100.2775  21.8784  3.1100  0.3120  0.1446  -48.1834   57.6547
# 12335   91.6558  18.8293  2.7097  0.4386  0.3420  -52.6841  -97.8373
# 12336   38.0195  12.6736  2.8747  0.4084  0.1928  -51.4840    8.3471
# ...         ...      ...     ...     ...     ...       ...       ...
# 19015   21.3846  10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452   6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455  47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135  76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814  53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist  class
# 12332   11.8175  14.1224  231.9028      0
# 12333  -15.0647  88.4636  274.9392      0
# ...

# %%
for col in df[:10]:
    plt.hist([df_gamma[col],df_hadron[col]], color = ['blue', 'red'], bins = 'auto', label = ['Gamma', 'Hadron'])
#     plt.hist(df_hadron[col], color = 'red', bins = 'auto', label = 'Hadron')
    plt.legend()
    plt.title(col)
    plt.show()
